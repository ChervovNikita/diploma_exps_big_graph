# %%
import numpy as np

train_nodes = np.load('splits/train_nodes.npy')
val_nodes = np.load('splits/val_nodes.npy')
test_nodes = np.load('splits/test_nodes.npy')
unknown_nodes = np.load('splits/unknown_nodes.npy')
node_labels = np.load('splits/node_labels.npy')
node_labels_masked = np.load('splits/node_labels_masked.npy')

# %%
set(node_labels_masked[train_nodes].tolist())
# Out:
# {0, 1, 2, 3}

# %%
set(node_labels_masked[test_nodes].tolist())
# Out:
# {-1}

# %%
set(node_labels_masked[unknown_nodes].tolist())
# Out:
# {-1}

# %%
set(node_labels[test_nodes].tolist())
# Out:
# {0, 1, 2, 3}

# %%
set(node_labels[test_nodes].tolist())
# Out:
# {0, 1, 2, 3}

# %%
set(node_labels[unknown_nodes].tolist())
# Out:
# {-1}

# %%
import pandas as pd
pd.read_csv('splits/edges_data.csv')
# Out:
#          node_id1  node_id2   ibd_sum  ibd_n
# 0               0         4   8.31217      1
# 1             124       128   8.12189      1
# 2             170       173   8.01403      1
# 3             341       342   8.75644      1
# 4             378       379   8.32970      1
# ...           ...       ...       ...    ...
# 6802902     64915    110837  17.68860      1
# 6802903     64915    200017  12.17790      1
# 6802904    227105     84204   9.22315      1
# 6802905     41191    115610   8.36391      1
# 6802906    187032    194365  10.09760      1
#
# [6802907 rows x 4 columns]
