# %%
import pandas as pd
import numpy as np

pca_data = pd.read_csv('3382_sampeles_in_pca_plot_over_80_central_russia_pca_data_anonymized.eigenvec', sep=r'\s+')

# %%
pca_nodes = set(pca_data['IID'].to_list())

# %%
data = pd.read_csv('../CR_real_masks_more_labeled_veritices_agreed.csv')

# %%
data = data[data['node_id1'].isin(pca_nodes) & data['node_id2'].isin(pca_nodes)]

# %%
data.to_csv('../CR_real_masks_more_labeled_veritices_agreed_with_pca_features.csv')
